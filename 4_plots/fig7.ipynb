# %% [markdown]
# # Figure 7

# %%
# %run 'flow_fig_init.py'

# %%
meth = "kendall"

fig = go.Figure()
feature = "f_integral"
area = "GB"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=["bottom left", "bottom center"],
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Great Britain',
            # legendgroup=1,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[0],
            marker_line_color=px.colors.qualitative.T10[0],
        )
    )

area = "Nordic"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
corr_importance_df["tp"] = ["top center", "top left"]
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=c.tp,
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Nordic',
            # legendgroup=2,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[1],
            marker_line_color=px.colors.qualitative.T10[1],
        )
    )

area = "GB-CE"
feature = "f_integral_GB"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
corr_importance_df["tp"] = ["middle right", "top left"]
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=c.tp,
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Great Britain',
            # legendgroup=1,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[0],
            marker_line_color=px.colors.qualitative.T10[0],
        )
    )

feature = "f_integral_CE"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            -pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
corr_importance_df["tp"] = ["bottom left", "top center"]
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=c.tp,
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Continental Europe',
            # legendgroup=3,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[2],
            marker_line_color=px.colors.qualitative.T10[2],
        )
    )

area = "Nordic-CE"
feature = "f_integral_Nordic"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
corr_importance_df["tp"] = [
    "top center",
    "top center",
    "top center",
    "middle left",
    "middle left",
    "top center",
    "top center",
]
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=c.tp,
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Nordic',
            # legendgroup=2,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[1],
            marker_line_color=px.colors.qualitative.T10[1],
        )
    )
feature = "f_integral_CE"
corr_importance_df = pd.DataFrame(
    {
        "name": [targ for targ in targets[area]],
        "correlation": [
            -pd.read_hdf(
                version_folder.format(area, targ, version) + "X_test_full_links.h5"
            )
            .loc[:, feature]
            .corr(
                shap_vals_df(area, version, targ, "_full").loc[:, feature], method=meth
            )
            for targ in targets[area]
        ],
        "importance": [
            (
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                / shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .sum()
            ).loc[feature]
            for targ in targets[area]
        ],
        "rank": [
            list(
                shap_vals_df(area, version, targ, "_full")
                .abs()
                .mean()
                .sort_values(ascending=False)
                .index
            ).index(feature)
            + 1
            for targ in targets[area]
        ],
    }
)
corr_importance_df["tp"] = [
    "bottom center",
    "top center",
    "top center",
    "bottom center",
    "top center",
    "top center",
    "bottom center",
]
for c in corr_importance_df.iloc:
    fig.add_trace(
        go.Scatter(
            x=[c.correlation],
            y=[c.importance],
            # text=['{}: {}'.format(c.name[i], c['rank'][i]) for i in range(len(c))],
            text=str(c["rank"]),
            textposition=c.tp,
            mode="markers+text",
            marker_symbol=linksymbols[c["name"]],
            showlegend=False,
            # legendgrouptitle_text='Continental Europe',
            # legendgroup=3,
            name=c["name"],
            marker_color=px.colors.qualitative.T10[2],
            marker_line_color=px.colors.qualitative.T10[2],
        )
    )
fig.add_vline(x=0, line_width=1, line_dash="dot", line_color="gray")


# fig.update_traces(
#     marker_symbol = 'x-thin',
#     marker_line_width=3
#     )
fig.update_yaxes(type="log")
fig.update_xaxes(range=[-1, 1])
fig.update_layout(
    {
        "yaxis": {
            "title": "Feature Importance",
            "title_standoff": 25,
            "linewidth": 1,
            "linecolor": "black",
            "mirror": True,
            "ticks": "outside",
            "showline": True,
        },
        "xaxis": {
            "title": "Correlation &#964;",
            "title_standoff": 25,
            "linewidth": 1,
            "linecolor": "black",
            "mirror": True,
            "ticks": "outside",
            "showline": True,
        },
    }
)

fig.update_layout(template="plotly_white", width=1240, height=1100)

# fig.add_annotation(x=-0.5, y=-1,
#             text='test',
#             showarrow=False,
#             yshift=0)


fig.update_traces(marker_size=20)

for i, area in enumerate(areas):
    for targ in targets[area]:
        fig.add_trace(
            go.Scatter(
                x=[None],
                y=[None],
                mode="markers",
                marker_symbol=linksymbols[targ],
                marker_size=25,
                legendgrouptitle_text="<b>{}</b>".format(
                    area_name[area]
                    .replace("GB", "Great Britain")
                    .replace("IE", "Ireland")
                    .replace("CE", "Continental Europe")
                    .replace("/", "<br>")
                ),
                legendgroup=i + 1,
                name=targ,
                marker_color="black",
                marker_line_color="black",
            )
        )

for i, area in enumerate(["Great Britain", "Nordic", "Continental Europe"]):
    fig.add_trace(
        go.Scatter(
            x=[None],
            y=[None],
            mode="markers",
            marker_symbol="square",
            marker_size=25,
            legendgrouptitle_text="<b>Frequency integral in:</b>",
            legendgroup=6,
            name=area,
            marker_color=px.colors.qualitative.T10[i],
            marker_line_color=px.colors.qualitative.T10[i],
        )
    )


fig.update_layout(font=dict(size=20, color="black"))
fig.update_annotations(font_size=20)
fig.update_layout(legend_font_size=20)
fig.update_layout(legend_tracegroupgap=25)
fig.update_layout(margin_t=0)
fig.update_layout(legend_title="<b>HVDC links between:</b><br>")


print("creating plot...")
scope = pio.kaleido.scope
scope._shutdown_kaleido()
pio.write_image(fig, "fig7.pdf", format="pdf", validate=False, engine="kaleido")
time.sleep(1)
pio.write_image(fig, "fig7.pdf", format="pdf", validate=False, engine="kaleido")
scope._shutdown_kaleido()
# Out:
# creating plot...
