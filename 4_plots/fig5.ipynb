# %% [markdown]
# # Figure 5

# %%
# %run 'stability_fig_init.py'

# %%
colorsc = cc.CET_D1A
cmin = -2
cmax = 2

area = "Nordic"
targ = "f_integral"

X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)

# load data
y_pred = pd.read_hdf(fit_folder.format(area, version, targ) + "y_pred.h5")
y_test = pd.read_hdf(version_folder.format(area, version) + "y_test.h5").loc[:, targ]
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)
X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")

important_feature = "IPS_UPS_unscheduled_flow"
color_feature = "IPS_UPS_import_export_total"
fig = make_subplots(
    cols=3, rows=2, shared_xaxes=True, horizontal_spacing=0.07, vertical_spacing=0
)

fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=y_test,
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=False,
    ),
    row=1,
    col=1,
)
fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=shap_vals[important_feature],
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=False,
        marker_colorbar={"title": "Baltic physical inflow"},
    ),
    row=2,
    col=1,
)

area = "GB"
targ = "f_integral"

X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)

# load data
y_pred = pd.read_hdf(fit_folder.format(area, version, targ) + "y_pred.h5")
y_test = pd.read_hdf(version_folder.format(area, version) + "y_test.h5").loc[:, targ]
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)
X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")

important_feature = "CE_unscheduled_flow"
color_feature = "CE_import_export_total"

fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=y_test,
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=False,
    ),
    row=1,
    col=2,
)
fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=shap_vals[important_feature],
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=True,
        marker_colorbar={"title": "Scheduled inflow [GW]", "title_side": "right"},
    ),
    row=2,
    col=2,
)

area = "Nordic"
targ = "f_integral"

X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)

# load data
y_pred = pd.read_hdf(fit_folder.format(area, version, targ) + "y_pred.h5")
y_test = pd.read_hdf(version_folder.format(area, version) + "y_test.h5").loc[:, targ]
with open(
    fit_folder.format(area, version, targ) + "shap_values_gtb_full.pkl", "rb"
) as handle:
    sh = pickle.load(handle)
shap_vals = pd.DataFrame(data=sh.values, index=X_test.index, columns=sh.feature_names)
X_test = pd.read_hdf(version_folder.format(area, version) + "X_test_full.h5")

important_feature = "CE_unscheduled_flow"
color_feature = "CE_import_export_total"

fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=y_test,
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=False,
    ),
    row=1,
    col=3,
)
fig.add_trace(
    go.Scatter(
        x=X_test[important_feature],
        y=shap_vals[important_feature],
        mode="markers",
        marker_size=4,
        marker_color=X_test[color_feature] / 1000,
        marker_colorscale=colorsc,
        marker_cmin=cmin,
        marker_cmax=cmax,
        marker_opacity=0.8,
        marker_showscale=True,
        marker_colorbar={"title": "Scheduled inflow [GW]", "title_side": "right"},
    ),
    row=2,
    col=3,
)

fig.update_layout(template="plotly_white", width=1240, height=600, showlegend=False)

fig.update_layout(
    xaxis1=dict(
        range=[-60, 80],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-40, 0, 40, 80],
    ),
    yaxis1=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        title="Integral<br><i>outflow grid</i>",
        title_standoff=40,
        tickmode="array",
        tickvals=[-200, 0, 200, 400],
    ),
    xaxis4=dict(
        range=[-60, 80],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        title_standoff=60,
        title="Nordic to Baltic<br>unscheduled flow [MW]",
        tickmode="array",
        tickvals=[-40, 0, 40, 80],
    ),
    yaxis4=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        title="SHAP values of Integral<br><i>outflow grid</i>",
        title_standoff=40,
    ),
)

fig.update_layout(
    xaxis2=dict(
        range=[-80, 40],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-80, -40, 0, 40, 80],
    ),
    yaxis2=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-200, 0, 200, 400],
    ),
    xaxis5=dict(
        range=[-80, 40],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-80, -40, 0, 40, 80],
        title_standoff=60,
        title="GB to CE<br>unscheduled flow [MW]",
    ),
    yaxis5=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-100, 0, 100],
    ),
)
fig.update_layout(
    xaxis3=dict(
        range=[-1500, 1500],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-1000, 0, 1000],
    ),
    yaxis3=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-200, 0, 200, 400],
    ),
    xaxis6=dict(
        range=[-1500, 1500],
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
        tickmode="array",
        tickvals=[-1000, 0, 1000],
        title_standoff=60,
        title="Nordic to CE<br>unscheduled flow [MW]",
    ),
    yaxis6=dict(
        linewidth=1,
        linecolor="black",
        mirror=True,
        ticks="outside",
        showline=True,
        gridwidth=1,
    ),
)


fig.update_layout(font=dict(size=20, color="black"))
fig.update_annotations(font_size=20)
fig.update_layout(margin_t=0)
fig.update_layout(margin_r=50)

fig.add_annotation(
    x=0.05,
    y=1,
    text="<b>a</b>",
    showarrow=False,
    xanchor="left",
    xref="x domain",
    yref="y domain",
    font_size=50,
)
fig.add_annotation(
    x=0.05,
    y=1,
    text="<b>b</b>",
    showarrow=False,
    xanchor="left",
    xref="x2 domain",
    yref="y2 domain",
    font_size=50,
)
fig.add_annotation(
    x=0.05,
    y=1,
    text="<b>c</b>",
    showarrow=False,
    xanchor="left",
    xref="x3 domain",
    yref="y3 domain",
    font_size=50,
)


print("creating plot...")
scope = pio.kaleido.scope
scope._shutdown_kaleido()
pio.write_image(fig, "fig5.pdf", format="pdf", validate=False, engine="kaleido")
time.sleep(1)
pio.write_image(fig, "fig5.pdf", format="pdf", validate=False, engine="kaleido")
scope._shutdown_kaleido()
# Out:
# creating plot...
